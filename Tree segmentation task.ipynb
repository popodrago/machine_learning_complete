# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/tree-binary-segmentation/images/images/1269.jpg
# /kaggle/input/tree-binary-segmentation/images/images/623.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2193.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2008.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2081.jpg
# /kaggle/input/tree-binary-segmentation/images/images/764.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1700.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1786.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1075.jpg
# /kaggle/input/tree-binary-segmentation/images/images/771.jpg
# /kaggle/input/tree-binary-segmentation/images/images/208.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2628.jpg
# /kaggle/input/tree-binary-segmentation/images/images/820.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1789.jpg
# /kaggle/input/tree-binary-segmentation/images/images/473.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1792.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2029.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1411.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1031.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1833.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2675.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2172.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1749.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1501.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2021.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1995.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1385.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2278.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1971.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1383.jpg
# /kaggle/input/tree-binary-segmentation/images/images/333.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1354.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1024.jpg
# /kaggle/input/tree-binary-segmentation/images/images/537.jpg
# /kaggle/input/tree-binary-segmentation/images/images/45.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2375.jpg
# /kaggle/input/tree-binary-segmentation/images/images/369.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1626.jpg
# /kaggle/input/tree-binary-segmentation/images/images/56.jpg
# /kaggle/input/tree-binary-segmentation/images/images/654.jpg
# /kaggle/input/tree-binary-segmentation/images/images/89.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1711.jpg
# /kaggle/input/tree-binary-segmentation/images/images/20.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1339.jpg
# /kaggle/input/tree-binary-segmentation/images/images/275.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2532.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1161.jpg
# /kaggle/input/tree-binary-segmentation/images/images/785.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2262.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2213.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1940.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1777.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1380.jpg
# /kaggle/input/tree-binary-segmentation/images/images/212.jpg
# /kaggle/input/tree-binary-segmentation/images/images/239.jpg
# /kaggle/input/tree-binary-segmentation/images/images/792.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2057.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1009.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2094.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1157.jpg
# /kaggle/input/tree-binary-segmentation/images/images/58.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2302.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2695.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1304.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1340.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1760.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2028.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1173.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1790.jpg
# /kaggle/input/tree-binary-segmentation/images/images/150.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2137.jpg
# /kaggle/input/tree-binary-segmentation/images/images/6.jpg
# /kaggle/input/tree-binary-segmentation/images/images/109.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2654.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1650.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1211.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2319.jpg
# /kaggle/input/tree-binary-segmentation/images/images/149.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1488.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1862.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1167.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1644.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1539.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2640.jpg
# /kaggle/input/tree-binary-segmentation/images/images/187.jpg
# /kaggle/input/tree-binary-segmentation/images/images/521.jpg
# /kaggle/input/tree-binary-segmentation/images/images/436.jpg
# /kaggle/input/tree-binary-segmentation/images/images/76.jpg
# /kaggle/input/tree-binary-segmentation/images/images/539.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1355.jpg
# /kaggle/input/tree-binary-segmentation/images/images/355.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2041.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1565.jpg
# /kaggle/input/tree-binary-segmentation/images/images/516.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1409.jpg
# /kaggle/input/tree-binary-segmentation/images/images/71.jpg
# /kaggle/input/tree-binary-segmentation/images/images/708.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1222.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1154.jpg
# /kaggle/input/tree-binary-segmentation/images/images/474.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1840.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2580.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1124.jpg
# /kaggle/input/tree-binary-segmentation/images/images/501.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1395.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2363.jpg
# /kaggle/input/tree-binary-segmentation/images/images/915.jpg
# /kaggle/input/tree-binary-segmentation/images/images/815.jpg
# /kaggle/input/tree-binary-segmentation/images/images/760.jpg
# /kaggle/input/tree-binary-segmentation/images/images/342.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1459.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2704.jpg
# /kaggle/input/tree-binary-segmentation/images/images/817.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2003.jpg
# /kaggle/input/tree-binary-segmentation/images/images/429.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2000.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1055.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2560.jpg
# /kaggle/input/tree-binary-segmentation/images/images/646.jpg
# /kaggle/input/tree-binary-segmentation/images/images/682.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1548.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1934.jpg
# /kaggle/input/tree-binary-segmentation/images/images/544.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1794.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1715.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2279.jpg
# /kaggle/input/tree-binary-segmentation/images/images/377.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1026.jpg
# /kaggle/input/tree-binary-segmentation/images/images/272.jpg
# /kaggle/input/tree-binary-segmentation/images/images/795.jpg
# /kaggle/input/tree-binary-segmentation/images/images/270.jpg
# /kaggle/input/tree-binary-segmentation/images/images/182.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2182.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1936.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1162.jpg
# /kaggle/input/tree-binary-segmentation/images/images/215.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2067.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2558.jpg
# /kaggle/input/tree-binary-segmentation/images/images/489.jpg
# /kaggle/input/tree-binary-segmentation/images/images/576.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2571.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1834.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2397.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2526.jpg
# /kaggle/input/tree-binary-segmentation/images/images/185.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1484.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1920.jpg
# /kaggle/input/tree-binary-segmentation/images/images/613.jpg
# /kaggle/input/tree-binary-segmentation/images/images/930.jpg
# /kaggle/input/tree-binary-segmentation/images/images/243.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1702.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2510.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1010.jpg
# /kaggle/input/tree-binary-segmentation/images/images/153.jpg
# /kaggle/input/tree-binary-segmentation/images/images/703.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1451.jpg
# /kaggle/input/tree-binary-segmentation/images/images/189.jpg
# /kaggle/input/tree-binary-segmentation/images/images/143.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2486.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1025.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2444.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1343.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1579.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1774.jpg
# /kaggle/input/tree-binary-segmentation/images/images/476.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2403.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2626.jpg
# /kaggle/input/tree-binary-segmentation/images/images/717.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2716.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1473.jpg
# /kaggle/input/tree-binary-segmentation/images/images/327.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2178.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1669.jpg
# /kaggle/input/tree-binary-segmentation/images/images/253.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2673.jpg
# /kaggle/input/tree-binary-segmentation/images/images/343.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1815.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2643.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1746.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2271.jpg
# /kaggle/input/tree-binary-segmentation/images/images/115.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2517.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1905.jpg
# /kaggle/input/tree-binary-segmentation/images/images/131.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2087.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1058.jpg
# /kaggle/input/tree-binary-segmentation/images/images/446.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1498.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1166.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1812.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1601.jpg
# /kaggle/input/tree-binary-segmentation/images/images/626.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1443.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2174.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2150.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2394.jpg
# /kaggle/input/tree-binary-segmentation/images/images/425.jpg
# /kaggle/input/tree-binary-segmentation/images/images/5.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1559.jpg
# /kaggle/input/tree-binary-segmentation/images/images/824.jpg
# /kaggle/input/tree-binary-segmentation/images/images/366.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2530.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1101.jpg
# /kaggle/input/tree-binary-segmentation/images/images/850.jpg
# /kaggle/input/tree-binary-segmentation/images/images/885.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1327.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1781.jpg
# /kaggle/input/tree-binary-segmentation/images/images/151.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1097.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2552.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1376.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2655.jpg
# /kaggle/input/tree-binary-segmentation/images/images/426.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2204.jpg
# /kaggle/input/tree-binary-segmentation/images/images/732.jpg
# /kaggle/input/tree-binary-segmentation/images/images/503.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2573.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1297.jpg
# /kaggle/input/tree-binary-segmentation/images/images/8.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2011.jpg
# /kaggle/input/tree-binary-segmentation/images/images/641.jpg
# /kaggle/input/tree-binary-segmentation/images/images/892.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2131.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1478.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2471.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1413.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1604.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2476.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2470.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2608.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2595.jpg
# /kaggle/input/tree-binary-segmentation/images/images/988.jpg
# /kaggle/input/tree-binary-segmentation/images/images/622.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1129.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2501.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2323.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2627.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1655.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1144.jpg
# /kaggle/input/tree-binary-segmentation/images/images/440.jpg
# /kaggle/input/tree-binary-segmentation/images/images/260.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1716.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2282.jpg
# /kaggle/input/tree-binary-segmentation/images/images/534.jpg
# /kaggle/input/tree-binary-segmentation/images/images/202.jpg
# /kaggle/input/tree-binary-segmentation/images/images/84.jpg
# /kaggle/input/tree-binary-segmentation/images/images/577.jpg
# /kaggle/input/tree-binary-segmentation/images/images/751.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2698.jpg
# /kaggle/input/tree-binary-segmentation/images/images/944.jpg
# /kaggle/input/tree-binary-segmentation/images/images/237.jpg
# /kaggle/input/tree-binary-segmentation/images/images/273.jpg
# /kaggle/input/tree-binary-segmentation/images/images/286.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1032.jpg
# /kaggle/input/tree-binary-segmentation/images/images/283.jpg
# /kaggle/input/tree-binary-segmentation/images/images/486.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2338.jpg
# /kaggle/input/tree-binary-segmentation/images/images/513.jpg
# /kaggle/input/tree-binary-segmentation/images/images/766.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2460.jpg
# /kaggle/input/tree-binary-segmentation/images/images/85.jpg
# /kaggle/input/tree-binary-segmentation/images/images/564.jpg
# /kaggle/input/tree-binary-segmentation/images/images/359.jpg
# /kaggle/input/tree-binary-segmentation/images/images/67.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1709.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2625.jpg
# /kaggle/input/tree-binary-segmentation/images/images/265.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2505.jpg
# /kaggle/input/tree-binary-segmentation/images/images/289.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2020.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1125.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1331.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2587.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2457.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2537.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2633.jpg
# /kaggle/input/tree-binary-segmentation/images/images/973.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1424.jpg
# /kaggle/input/tree-binary-segmentation/images/images/118.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2186.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1037.jpg
# /kaggle/input/tree-binary-segmentation/images/images/950.jpg
# /kaggle/input/tree-binary-segmentation/images/images/768.jpg
# /kaggle/input/tree-binary-segmentation/images/images/361.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1089.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1136.jpg
# /kaggle/input/tree-binary-segmentation/images/images/591.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2091.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1171.jpg
# /kaggle/input/tree-binary-segmentation/images/images/82.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1387.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2564.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1744.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1391.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1795.jpg
# /kaggle/input/tree-binary-segmentation/images/images/723.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2475.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2555.jpg
# /kaggle/input/tree-binary-segmentation/images/images/443.jpg
# /kaggle/input/tree-binary-segmentation/images/images/295.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2596.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2168.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1134.jpg
# /kaggle/input/tree-binary-segmentation/images/images/176.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1389.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1475.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2237.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1554.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2139.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1243.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1499.jpg
# /kaggle/input/tree-binary-segmentation/images/images/279.jpg
# /kaggle/input/tree-binary-segmentation/images/images/668.jpg
# /kaggle/input/tree-binary-segmentation/images/images/757.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2681.jpg
# /kaggle/input/tree-binary-segmentation/images/images/30.jpg
# /kaggle/input/tree-binary-segmentation/images/images/97.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2417.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1002.jpg
# /kaggle/input/tree-binary-segmentation/images/images/334.jpg
# /kaggle/input/tree-binary-segmentation/images/images/106.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2391.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1172.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1527.jpg
# /kaggle/input/tree-binary-segmentation/images/images/806.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2696.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2183.jpg
# /kaggle/input/tree-binary-segmentation/images/images/163.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2386.jpg
# /kaggle/input/tree-binary-segmentation/images/images/113.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2500.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1845.jpg
# /kaggle/input/tree-binary-segmentation/images/images/160.jpg
# /kaggle/input/tree-binary-segmentation/images/images/518.jpg
# /kaggle/input/tree-binary-segmentation/images/images/994.jpg
# /kaggle/input/tree-binary-segmentation/images/images/38.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2228.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2033.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1401.jpg
# /kaggle/input/tree-binary-segmentation/images/images/463.jpg
# /kaggle/input/tree-binary-segmentation/images/images/349.jpg
# /kaggle/input/tree-binary-segmentation/images/images/490.jpg
# /kaggle/input/tree-binary-segmentation/images/images/328.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2592.jpg
# /kaggle/input/tree-binary-segmentation/images/images/211.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1041.jpg
# /kaggle/input/tree-binary-segmentation/images/images/829.jpg
# /kaggle/input/tree-binary-segmentation/images/images/788.jpg
# /kaggle/input/tree-binary-segmentation/images/images/811.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1196.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2214.jpg
# /kaggle/input/tree-binary-segmentation/images/images/978.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2232.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1312.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2495.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2694.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1648.jpg
# /kaggle/input/tree-binary-segmentation/images/images/863.jpg
# /kaggle/input/tree-binary-segmentation/images/images/42.jpg
# /kaggle/input/tree-binary-segmentation/images/images/291.jpg
# /kaggle/input/tree-binary-segmentation/images/images/949.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2089.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1778.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1071.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1575.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2503.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1336.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2703.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1569.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2270.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2515.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1680.jpg
# /kaggle/input/tree-binary-segmentation/images/images/197.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1019.jpg
# /kaggle/input/tree-binary-segmentation/images/images/704.jpg
# /kaggle/input/tree-binary-segmentation/images/images/630.jpg
# /kaggle/input/tree-binary-segmentation/images/images/33.jpg
# /kaggle/input/tree-binary-segmentation/images/images/10.jpg
# /kaggle/input/tree-binary-segmentation/images/images/234.jpg
# /kaggle/input/tree-binary-segmentation/images/images/818.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2451.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1727.jpg
# /kaggle/input/tree-binary-segmentation/images/images/178.jpg
# /kaggle/input/tree-binary-segmentation/images/images/54.jpg
# /kaggle/input/tree-binary-segmentation/images/images/990.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2642.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2688.jpg
# /kaggle/input/tree-binary-segmentation/images/images/672.jpg
# /kaggle/input/tree-binary-segmentation/images/images/271.jpg
# /kaggle/input/tree-binary-segmentation/images/images/683.jpg
# /kaggle/input/tree-binary-segmentation/images/images/251.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2196.jpg
# /kaggle/input/tree-binary-segmentation/images/images/759.jpg
# /kaggle/input/tree-binary-segmentation/images/images/665.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2645.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1371.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2431.jpg
# /kaggle/input/tree-binary-segmentation/images/images/0.jpg
# /kaggle/input/tree-binary-segmentation/images/images/130.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1168.jpg
# /kaggle/input/tree-binary-segmentation/images/images/62.jpg
# /kaggle/input/tree-binary-segmentation/images/images/916.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2035.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1677.jpg
# /kaggle/input/tree-binary-segmentation/images/images/833.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1076.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1183.jpg
# /kaggle/input/tree-binary-segmentation/images/images/948.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1268.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1603.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2661.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2079.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2312.jpg
# /kaggle/input/tree-binary-segmentation/images/images/951.jpg
# /kaggle/input/tree-binary-segmentation/images/images/589.jpg
# /kaggle/input/tree-binary-segmentation/images/images/278.jpg
# /kaggle/input/tree-binary-segmentation/images/images/743.jpg
# /kaggle/input/tree-binary-segmentation/images/images/500.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2211.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1660.jpg
# /kaggle/input/tree-binary-segmentation/images/images/156.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1755.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2624.jpg
# /kaggle/input/tree-binary-segmentation/images/images/380.jpg
# /kaggle/input/tree-binary-segmentation/images/images/558.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1118.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2125.jpg
# /kaggle/input/tree-binary-segmentation/images/images/120.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2159.jpg
# /kaggle/input/tree-binary-segmentation/images/images/998.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1592.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2683.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2113.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1108.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1571.jpg
# /kaggle/input/tree-binary-segmentation/images/images/456.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2332.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2616.jpg
# /kaggle/input/tree-binary-segmentation/images/images/35.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2097.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2286.jpg
# /kaggle/input/tree-binary-segmentation/images/images/629.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1018.jpg
# /kaggle/input/tree-binary-segmentation/images/images/290.jpg
# /kaggle/input/tree-binary-segmentation/images/images/61.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2512.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2051.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1827.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1873.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1078.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2109.jpg
# /kaggle/input/tree-binary-segmentation/images/images/190.jpg
# /kaggle/input/tree-binary-segmentation/images/images/124.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2235.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1241.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1191.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1295.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1366.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2400.jpg
# /kaggle/input/tree-binary-segmentation/images/images/441.jpg
# /kaggle/input/tree-binary-segmentation/images/images/924.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2641.jpg
# /kaggle/input/tree-binary-segmentation/images/images/965.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1067.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1359.jpg
# /kaggle/input/tree-binary-segmentation/images/images/353.jpg
# /kaggle/input/tree-binary-segmentation/images/images/191.jpg
# /kaggle/input/tree-binary-segmentation/images/images/512.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2636.jpg
# /kaggle/input/tree-binary-segmentation/images/images/427.jpg
# /kaggle/input/tree-binary-segmentation/images/images/59.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2294.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1846.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2016.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2195.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2347.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2185.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1200.jpg
# /kaggle/input/tree-binary-segmentation/images/images/604.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1330.jpg
# /kaggle/input/tree-binary-segmentation/images/images/680.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2181.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2346.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1820.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1895.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1706.jpg
# /kaggle/input/tree-binary-segmentation/images/images/819.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2376.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1944.jpg
# /kaggle/input/tree-binary-segmentation/images/images/595.jpg
# /kaggle/input/tree-binary-segmentation/images/images/379.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1688.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1584.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2697.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1288.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1878.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2671.jpg
# /kaggle/input/tree-binary-segmentation/images/images/73.jpg
# /kaggle/input/tree-binary-segmentation/images/images/313.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1708.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1123.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2361.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2650.jpg
# /kaggle/input/tree-binary-segmentation/images/images/601.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1310.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1738.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1197.jpg
# /kaggle/input/tree-binary-segmentation/images/images/871.jpg
# /kaggle/input/tree-binary-segmentation/images/images/188.jpg
# /kaggle/input/tree-binary-segmentation/images/images/274.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2112.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1094.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1080.jpg
# /kaggle/input/tree-binary-segmentation/images/images/98.jpg
# /kaggle/input/tree-binary-segmentation/images/images/375.jpg
# /kaggle/input/tree-binary-segmentation/images/images/396.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1235.jpg
# /kaggle/input/tree-binary-segmentation/images/images/41.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1997.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2340.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2257.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1160.jpg
# /kaggle/input/tree-binary-segmentation/images/images/480.jpg
# /kaggle/input/tree-binary-segmentation/images/images/527.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1318.jpg
# /kaggle/input/tree-binary-segmentation/images/images/620.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1206.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2591.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2162.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2541.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1799.jpg
# /kaggle/input/tree-binary-segmentation/images/images/248.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1808.jpg
# /kaggle/input/tree-binary-segmentation/images/images/123.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2334.jpg
# /kaggle/input/tree-binary-segmentation/images/images/710.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1549.jpg
# /kaggle/input/tree-binary-segmentation/images/images/230.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1091.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2019.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1580.jpg
# /kaggle/input/tree-binary-segmentation/images/images/580.jpg
# /kaggle/input/tree-binary-segmentation/images/images/685.jpg
# /kaggle/input/tree-binary-segmentation/images/images/408.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1710.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1551.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1012.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1471.jpg
# /kaggle/input/tree-binary-segmentation/images/images/509.jpg
# /kaggle/input/tree-binary-segmentation/images/images/872.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1582.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1629.jpg
# /kaggle/input/tree-binary-segmentation/images/images/256.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1328.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1034.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1048.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1562.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2352.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1673.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1947.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2392.jpg
# /kaggle/input/tree-binary-segmentation/images/images/776.jpg
# /kaggle/input/tree-binary-segmentation/images/images/559.jpg
# /kaggle/input/tree-binary-segmentation/images/images/247.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1933.jpg
# /kaggle/input/tree-binary-segmentation/images/images/477.jpg
# /kaggle/input/tree-binary-segmentation/images/images/94.jpg
# /kaggle/input/tree-binary-segmentation/images/images/904.jpg
# /kaggle/input/tree-binary-segmentation/images/images/932.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1084.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1987.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2128.jpg
# /kaggle/input/tree-binary-segmentation/images/images/362.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2547.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1985.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1634.jpg
# /kaggle/input/tree-binary-segmentation/images/images/60.jpg
# /kaggle/input/tree-binary-segmentation/images/images/627.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1919.jpg
# /kaggle/input/tree-binary-segmentation/images/images/538.jpg
# /kaggle/input/tree-binary-segmentation/images/images/221.jpg
# /kaggle/input/tree-binary-segmentation/images/images/167.jpg
# /kaggle/input/tree-binary-segmentation/images/images/57.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1289.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2149.jpg
# /kaggle/input/tree-binary-segmentation/images/images/515.jpg
# /kaggle/input/tree-binary-segmentation/images/images/227.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1146.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1095.jpg
# /kaggle/input/tree-binary-segmentation/images/images/894.jpg
# /kaggle/input/tree-binary-segmentation/images/images/690.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1329.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2258.jpg
# /kaggle/input/tree-binary-segmentation/images/images/822.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2227.jpg
# /kaggle/input/tree-binary-segmentation/images/images/112.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1762.jpg
# /kaggle/input/tree-binary-segmentation/images/images/664.jpg
# /kaggle/input/tree-binary-segmentation/images/images/938.jpg
# /kaggle/input/tree-binary-segmentation/images/images/372.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1912.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2458.jpg
# /kaggle/input/tree-binary-segmentation/images/images/388.jpg
# /kaggle/input/tree-binary-segmentation/images/images/478.jpg
# /kaggle/input/tree-binary-segmentation/images/images/193.jpg
# /kaggle/input/tree-binary-segmentation/images/images/374.jpg
# /kaggle/input/tree-binary-segmentation/images/images/639.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2166.jpg
# /kaggle/input/tree-binary-segmentation/images/images/452.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1962.jpg
# /kaggle/input/tree-binary-segmentation/images/images/152.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1534.jpg
# /kaggle/input/tree-binary-segmentation/images/images/368.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1665.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1955.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2614.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2612.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2224.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1440.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1044.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2488.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1748.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1496.jpg
# /kaggle/input/tree-binary-segmentation/images/images/745.jpg
# /kaggle/input/tree-binary-segmentation/images/images/738.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2662.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2436.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1836.jpg
# /kaggle/input/tree-binary-segmentation/images/images/506.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1854.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2602.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1737.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2221.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1735.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1434.jpg
# /kaggle/input/tree-binary-segmentation/images/images/192.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2411.jpg
# /kaggle/input/tree-binary-segmentation/images/images/412.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1865.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2277.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1099.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1082.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2589.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2331.jpg
# /kaggle/input/tree-binary-segmentation/images/images/701.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2036.jpg
# /kaggle/input/tree-binary-segmentation/images/images/91.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1054.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1017.jpg
# /kaggle/input/tree-binary-segmentation/images/images/653.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1406.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1649.jpg
# /kaggle/input/tree-binary-segmentation/images/images/9.jpg
# /kaggle/input/tree-binary-segmentation/images/images/705.jpg
# /kaggle/input/tree-binary-segmentation/images/images/101.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1963.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1372.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2077.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1733.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2714.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1767.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2664.jpg
# /kaggle/input/tree-binary-segmentation/images/images/651.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2123.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1544.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1324.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2705.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2099.jpg
# /kaggle/input/tree-binary-segmentation/images/images/99.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2155.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1563.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2264.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1607.jpg
# /kaggle/input/tree-binary-segmentation/images/images/382.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1523.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1625.jpg
# /kaggle/input/tree-binary-segmentation/images/images/836.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2255.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1259.jpg
# /kaggle/input/tree-binary-segmentation/images/images/311.jpg
# /kaggle/input/tree-binary-segmentation/images/images/831.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1547.jpg
# /kaggle/input/tree-binary-segmentation/images/images/241.jpg
# /kaggle/input/tree-binary-segmentation/images/images/832.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2310.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1557.jpg
# /kaggle/input/tree-binary-segmentation/images/images/397.jpg
# /kaggle/input/tree-binary-segmentation/images/images/37.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2117.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2518.jpg
# /kaggle/input/tree-binary-segmentation/images/images/340.jpg
# /kaggle/input/tree-binary-segmentation/images/images/435.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2023.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2063.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2046.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2692.jpg
# /kaggle/input/tree-binary-segmentation/images/images/524.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1904.jpg
# /kaggle/input/tree-binary-segmentation/images/images/793.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2308.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1764.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2116.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1060.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1126.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2010.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1642.jpg
# /kaggle/input/tree-binary-segmentation/images/images/529.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2393.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2360.jpg
# /kaggle/input/tree-binary-segmentation/images/images/177.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2296.jpg
# /kaggle/input/tree-binary-segmentation/images/images/868.jpg
# /kaggle/input/tree-binary-segmentation/images/images/186.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1718.jpg
# /kaggle/input/tree-binary-segmentation/images/images/642.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2462.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2605.jpg
# /kaggle/input/tree-binary-segmentation/images/images/720.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1494.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2620.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1967.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2651.jpg
# /kaggle/input/tree-binary-segmentation/images/images/358.jpg
# /kaggle/input/tree-binary-segmentation/images/images/69.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1378.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2276.jpg
# /kaggle/input/tree-binary-segmentation/images/images/468.jpg
# /kaggle/input/tree-binary-segmentation/images/images/414.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2678.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1511.jpg
# /kaggle/input/tree-binary-segmentation/images/images/75.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1507.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1980.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2464.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1913.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1315.jpg
# /kaggle/input/tree-binary-segmentation/images/images/963.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1503.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1274.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1287.jpg
# /kaggle/input/tree-binary-segmentation/images/images/943.jpg
# /kaggle/input/tree-binary-segmentation/images/images/403.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1145.jpg
# /kaggle/input/tree-binary-segmentation/images/images/660.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1281.jpg
# /kaggle/input/tree-binary-segmentation/images/images/928.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1180.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2477.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1335.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2300.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2447.jpg
# /kaggle/input/tree-binary-segmentation/images/images/887.jpg
# /kaggle/input/tree-binary-segmentation/images/images/117.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1935.jpg
# /kaggle/input/tree-binary-segmentation/images/images/81.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1703.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1352.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1646.jpg
# /kaggle/input/tree-binary-segmentation/images/images/721.jpg
# /kaggle/input/tree-binary-segmentation/images/images/974.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1514.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2459.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2239.jpg
# /kaggle/input/tree-binary-segmentation/images/images/684.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1262.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1122.jpg
# /kaggle/input/tree-binary-segmentation/images/images/390.jpg
# /kaggle/input/tree-binary-segmentation/images/images/299.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1686.jpg
# /kaggle/input/tree-binary-segmentation/images/images/2176.jpg
# /kaggle/input/tree-binary-segmentation/images/images/254.jpg
# /kaggle/input/tree-binary-segmentation/images/images/410.jpg
# /kaggle/input/tree-binary-segmentation/images/images/381.jpg
# /kaggle/input/tree-binary-segmentation/images/images/535.jpg
# /kaggle/input/tree-binary-segmentation/images/images/393.jpg
# /kaggle/input/tree-binary-segmentation/images/images/424.jpg
# /kaggle/input/tree-binary-segmentation/images/images/494.jpg
# /kaggle/input/tree-binary-segmentation/images/images/1053.jpg
# ...
# /kaggle/input/tree-binary-segmentation/masks/masks/1222.png
# /kaggle/input/tree-binary-segmentation/masks/masks/390.png
# /kaggle/input/tree-binary-segmentation/masks/masks/237.png
# /kaggle/input/tree-binary-segmentation/masks/masks/451.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2450.png
# /kaggle/input/tree-binary-segmentation/masks/masks/692.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2503.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2468.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1982.png
# /kaggle/input/tree-binary-segmentation/masks/masks/474.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2282.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2126.png
# /kaggle/input/tree-binary-segmentation/masks/masks/292.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2615.png
# /kaggle/input/tree-binary-segmentation/masks/masks/421.png
# /kaggle/input/tree-binary-segmentation/masks/masks/999.png
# /kaggle/input/tree-binary-segmentation/masks/masks/201.png
# /kaggle/input/tree-binary-segmentation/masks/masks/539.png
# /kaggle/input/tree-binary-segmentation/masks/masks/519.png
# /kaggle/input/tree-binary-segmentation/masks/masks/845.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1395.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1340.png
# /kaggle/input/tree-binary-segmentation/masks/masks/295.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2275.png
# /kaggle/input/tree-binary-segmentation/masks/masks/394.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2056.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1718.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2181.png
# /kaggle/input/tree-binary-segmentation/masks/masks/273.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2251.png
# /kaggle/input/tree-binary-segmentation/masks/masks/269.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1758.png
# /kaggle/input/tree-binary-segmentation/masks/masks/459.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2141.png
# /kaggle/input/tree-binary-segmentation/masks/masks/413.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1058.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1336.png
# /kaggle/input/tree-binary-segmentation/masks/masks/773.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2214.png
# /kaggle/input/tree-binary-segmentation/masks/masks/78.png
# /kaggle/input/tree-binary-segmentation/masks/masks/212.png
# /kaggle/input/tree-binary-segmentation/masks/masks/47.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2639.png
# /kaggle/input/tree-binary-segmentation/masks/masks/786.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1942.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1797.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2357.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2457.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1210.png
# /kaggle/input/tree-binary-segmentation/masks/masks/207.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1110.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1487.png
# /kaggle/input/tree-binary-segmentation/masks/masks/149.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2604.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2215.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1805.png
# /kaggle/input/tree-binary-segmentation/masks/masks/487.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1792.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2498.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1786.png
# /kaggle/input/tree-binary-segmentation/masks/masks/812.png
# /kaggle/input/tree-binary-segmentation/masks/masks/13.png
# /kaggle/input/tree-binary-segmentation/masks/masks/842.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1691.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2412.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2601.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1974.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2528.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2018.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1571.png
# /kaggle/input/tree-binary-segmentation/masks/masks/974.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1853.png
# /kaggle/input/tree-binary-segmentation/masks/masks/535.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2188.png
# /kaggle/input/tree-binary-segmentation/masks/masks/843.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2562.png
# /kaggle/input/tree-binary-segmentation/masks/masks/260.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2527.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2271.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2032.png
# /kaggle/input/tree-binary-segmentation/masks/masks/830.png
# /kaggle/input/tree-binary-segmentation/masks/masks/253.png
# /kaggle/input/tree-binary-segmentation/masks/masks/206.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1034.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1834.png
# /kaggle/input/tree-binary-segmentation/masks/masks/789.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1894.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2643.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1365.png
# /kaggle/input/tree-binary-segmentation/masks/masks/557.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2167.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1274.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2163.png
# /kaggle/input/tree-binary-segmentation/masks/masks/980.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1309.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1175.png
# /kaggle/input/tree-binary-segmentation/masks/masks/613.png
# /kaggle/input/tree-binary-segmentation/masks/masks/600.png
# /kaggle/input/tree-binary-segmentation/masks/masks/874.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2583.png
# /kaggle/input/tree-binary-segmentation/masks/masks/381.png
# /kaggle/input/tree-binary-segmentation/masks/masks/342.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1252.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1074.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2458.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1267.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1866.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2225.png
# /kaggle/input/tree-binary-segmentation/masks/masks/346.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1497.png
# /kaggle/input/tree-binary-segmentation/masks/masks/134.png
# /kaggle/input/tree-binary-segmentation/masks/masks/721.png
# /kaggle/input/tree-binary-segmentation/masks/masks/898.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1124.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2258.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2399.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2288.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1912.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1938.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1781.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2227.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2246.png
# /kaggle/input/tree-binary-segmentation/masks/masks/694.png
# /kaggle/input/tree-binary-segmentation/masks/masks/590.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2504.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1172.png
# /kaggle/input/tree-binary-segmentation/masks/masks/566.png
# /kaggle/input/tree-binary-segmentation/masks/masks/921.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1426.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1957.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1765.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1762.png
# /kaggle/input/tree-binary-segmentation/masks/masks/259.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2159.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1889.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1579.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2442.png
# /kaggle/input/tree-binary-segmentation/masks/masks/25.png
# /kaggle/input/tree-binary-segmentation/masks/masks/871.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1613.png
# /kaggle/input/tree-binary-segmentation/masks/masks/285.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1297.png
# /kaggle/input/tree-binary-segmentation/masks/masks/341.png
# /kaggle/input/tree-binary-segmentation/masks/masks/54.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1160.png
# /kaggle/input/tree-binary-segmentation/masks/masks/462.png
# /kaggle/input/tree-binary-segmentation/masks/masks/851.png
# /kaggle/input/tree-binary-segmentation/masks/masks/558.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1861.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1350.png
# /kaggle/input/tree-binary-segmentation/masks/masks/111.png
# /kaggle/input/tree-binary-segmentation/masks/masks/611.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2055.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2618.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1644.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1825.png
# /kaggle/input/tree-binary-segmentation/masks/masks/887.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2586.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2035.png
# /kaggle/input/tree-binary-segmentation/masks/masks/62.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2474.png
# /kaggle/input/tree-binary-segmentation/masks/masks/205.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1373.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1265.png
# /kaggle/input/tree-binary-segmentation/masks/masks/699.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2414.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1711.png
# /kaggle/input/tree-binary-segmentation/masks/masks/369.png
# /kaggle/input/tree-binary-segmentation/masks/masks/750.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1262.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2610.png
# /kaggle/input/tree-binary-segmentation/masks/masks/0.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2033.png
# /kaggle/input/tree-binary-segmentation/masks/masks/963.png
# /kaggle/input/tree-binary-segmentation/masks/masks/141.png
# /kaggle/input/tree-binary-segmentation/masks/masks/693.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2232.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2361.png
# /kaggle/input/tree-binary-segmentation/masks/masks/532.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1408.png
# /kaggle/input/tree-binary-segmentation/masks/masks/309.png
# /kaggle/input/tree-binary-segmentation/masks/masks/560.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1211.png
# /kaggle/input/tree-binary-segmentation/masks/masks/19.png
# /kaggle/input/tree-binary-segmentation/masks/masks/110.png
# /kaggle/input/tree-binary-segmentation/masks/masks/544.png
# /kaggle/input/tree-binary-segmentation/masks/masks/308.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2161.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1988.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2078.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1659.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2422.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1911.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1998.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2339.png
# /kaggle/input/tree-binary-segmentation/masks/masks/26.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2073.png
# /kaggle/input/tree-binary-segmentation/masks/masks/568.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1960.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2677.png
# /kaggle/input/tree-binary-segmentation/masks/masks/918.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2004.png
# /kaggle/input/tree-binary-segmentation/masks/masks/388.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1916.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1453.png
# /kaggle/input/tree-binary-segmentation/masks/masks/79.png
# /kaggle/input/tree-binary-segmentation/masks/masks/633.png
# /kaggle/input/tree-binary-segmentation/masks/masks/824.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1396.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2027.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2016.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1609.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2632.png
# /kaggle/input/tree-binary-segmentation/masks/masks/729.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1414.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1477.png
# /kaggle/input/tree-binary-segmentation/masks/masks/883.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2621.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1709.png
# /kaggle/input/tree-binary-segmentation/masks/masks/257.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2663.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2139.png
# /kaggle/input/tree-binary-segmentation/masks/masks/993.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1281.png
# /kaggle/input/tree-binary-segmentation/masks/masks/305.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2293.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1676.png
# /kaggle/input/tree-binary-segmentation/masks/masks/477.png
# /kaggle/input/tree-binary-segmentation/masks/masks/42.png
# /kaggle/input/tree-binary-segmentation/masks/masks/175.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1261.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1621.png
# /kaggle/input/tree-binary-segmentation/masks/masks/961.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1551.png
# /kaggle/input/tree-binary-segmentation/masks/masks/518.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2155.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1602.png
# /kaggle/input/tree-binary-segmentation/masks/masks/957.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1876.png
# /kaggle/input/tree-binary-segmentation/masks/masks/226.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1493.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2179.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2570.png
# /kaggle/input/tree-binary-segmentation/masks/masks/428.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2264.png
# /kaggle/input/tree-binary-segmentation/masks/masks/217.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1424.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1710.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2652.png
# /kaggle/input/tree-binary-segmentation/masks/masks/1330.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2708.png
# /kaggle/input/tree-binary-segmentation/masks/masks/867.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2693.png
# /kaggle/input/tree-binary-segmentation/masks/masks/821.png
# /kaggle/input/tree-binary-segmentation/masks/masks/494.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2383.png
# /kaggle/input/tree-binary-segmentation/masks/masks/837.png
# /kaggle/input/tree-binary-segmentation/masks/masks/659.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2210.png
# /kaggle/input/tree-binary-segmentation/masks/masks/418.png
# /kaggle/input/tree-binary-segmentation/masks/masks/452.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2627.png
# /kaggle/input/tree-binary-segmentation/masks/masks/981.png
# /kaggle/input/tree-binary-segmentation/masks/masks/948.png
# /kaggle/input/tree-binary-segmentation/masks/masks/2392.png
# /kaggle/input/tree-binary-segmentation/masks/masks/306.png
# /kaggle/input/tree-binary-segmentation/masks/masks/497.png
# /kaggle/input/tree-binary-segmentation/masks/masks/304.png

# %%
import os
import pandas as pd
from PIL import Image

folder_path = '/kaggle/input/tree-binary-segmentation/images/images'
def csv(folder_path):
    image_files = sorted([
    f for f in os.listdir(folder_path)
    if f.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp'))
    ])

    image_data = []

    for file_name in image_files:
        full_path = os.path.join(folder_path, file_name)
    
        try:
            with Image.open(full_path) as img:
                img.verify()  

                image_data.append({'file':file_name,'full_path_mask': full_path})
        except Exception as e:
            print(f"corrupted: {file_name} -> {e}")

    df = pd.DataFrame(image_data)
    csv_path = 'image_paths.csv'

    return df

def csv_(folder_path):
    image_files = sorted([
    f for f in os.listdir(folder_path)
    if f.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp'))
    ])

    image_data = []

    for file_name in image_files:
        full_path = os.path.join(folder_path, file_name)
    
        try:
            with Image.open(full_path) as img:
                img.verify()  

                image_data.append({'file':file_name,'full_path': full_path})
        except Exception as e:
            print(f"corrupted: {file_name} -> {e}")

    df = pd.DataFrame(image_data)
    csv_path = 'image_paths.csv'

    return df

# %%
train_path = csv_(folder_path = '/kaggle/input/tree-binary-segmentation/images/images')

# %%
train_masks = csv(folder_path = '/kaggle/input/tree-binary-segmentation/masks/masks')

# %%
train_masks
# Out:
#           file                                     full_path_mask
# 0        0.png  /kaggle/input/tree-binary-segmentation/masks/m...
# 1        1.png  /kaggle/input/tree-binary-segmentation/masks/m...
# 2       10.png  /kaggle/input/tree-binary-segmentation/masks/m...
# 3      100.png  /kaggle/input/tree-binary-segmentation/masks/m...
# 4     1000.png  /kaggle/input/tree-binary-segmentation/masks/m...
# ...        ...                                                ...
# 2713   995.png  /kaggle/input/tree-binary-segmentation/masks/m...
# 2714   996.png  /kaggle/input/tree-binary-segmentation/masks/m...
# 2715   997.png  /kaggle/input/tree-binary-segmentation/masks/m...
# 2716   998.png  /kaggle/input/tree-binary-segmentation/masks/m...
# 2717   999.png  /kaggle/input/tree-binary-segmentation/masks/m...
#
# [2718 rows x 2 columns]

# %%
data = pd.concat([train_path,train_masks], axis= 1)

# %%
data.drop('file', axis=1, inplace = True)

# %%
data.shape
# Out:
# (2718, 2)

# %%
data.head()
# Out:
#                                            full_path  \
# 0  /kaggle/input/tree-binary-segmentation/images/...
# 1  /kaggle/input/tree-binary-segmentation/images/...
# 2  /kaggle/input/tree-binary-segmentation/images/...
# 3  /kaggle/input/tree-binary-segmentation/images/...
# 4  /kaggle/input/tree-binary-segmentation/images/...
#
#                                       full_path_mask
# 0  /kaggle/input/tree-binary-segmentation/masks/m...
# 1  /kaggle/input/tree-binary-segmentation/masks/m...
# 2  /kaggle/input/tree-binary-segmentation/masks/m...
# 3  /kaggle/input/tree-binary-segmentation/masks/m...
# 4  /kaggle/input/tree-binary-segmentation/masks/m...

# %%
from sklearn.model_selection import train_test_split

# %%
X = data.drop('full_path_mask', axis=1)
y = data.drop('full_path', axis = 1)

# %%
y.head()
# Out:
#                                       full_path_mask
# 0  /kaggle/input/tree-binary-segmentation/masks/m...
# 1  /kaggle/input/tree-binary-segmentation/masks/m...
# 2  /kaggle/input/tree-binary-segmentation/masks/m...
# 3  /kaggle/input/tree-binary-segmentation/masks/m...
# 4  /kaggle/input/tree-binary-segmentation/masks/m...

# %%
X_train, X_val, y_train, y_val = train_test_split(X,y,train_size=0.1,random_state = 42, shuffle = True)

# %%
from io import BytesIO

# %%
X_train['image'] =X_train['full_path'].apply(lambda x: open(x, 'rb').read())
X_train.drop(['full_path'], axis= 1, inplace = True)

# %%
y_train.head()
# Out:
#                                          full_path_mask
# 1218  /kaggle/input/tree-binary-segmentation/masks/m...
# 1158  /kaggle/input/tree-binary-segmentation/masks/m...
# 1415  /kaggle/input/tree-binary-segmentation/masks/m...
# 2461  /kaggle/input/tree-binary-segmentation/masks/m...
# 1527  /kaggle/input/tree-binary-segmentation/masks/m...

# %%
y_train['image'] =y_train['full_path_mask'].apply(lambda x: open(x, 'rb').read())
y_train.drop(['full_path_mask'], axis= 1, inplace = True)
X_val['image'] =X_val['full_path'].apply(lambda x: open(x, 'rb').read())
X_val.drop(['full_path'], axis= 1, inplace = True)
y_val['image'] =y_val['full_path_mask'].apply(lambda x: open(x, 'rb').read())
y_val.drop(['full_path_mask'], axis= 1, inplace = True)

# %%
X_train['image'] = X_train['image'].apply(lambda x: Image.open(BytesIO(x)).convert('RGB'))
y_train['image'] = y_train['image'].apply(lambda x: Image.open(BytesIO(x)).convert('L'))
X_val['image'] = X_val['image'].apply(lambda x: Image.open(BytesIO(x)).convert('RGB'))
y_val['image'] = y_val['image'].apply(lambda x: Image.open(BytesIO(x)).convert('L'))

# %%
X_train.iloc[0]['image']
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
y_train.iloc[0]['image']
# Out:
# <PIL.Image.Image image mode=L size=512x512>

# %%
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from torchvision.models import resnet50

# %%
transformer =transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor()
])

# %%
label_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor()
])

# %%
class dataset(Dataset):
    def __init__(self,dataframe, transformer = None , label_trans = None):
        super().__init__()
        self.dataframe = dataframe
        self.transformer = transformer
        self.label_trans = label_trans
    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self,idx):
        image = self.dataframe.iloc[idx]['image']
        label = self.dataframe.iloc[idx]['label']

        if self.transformer:
            image = self.transformer(image)
        if self.label_trans:    
            label = self.label_trans(label)
        return image, label

# %%
y_train['label'] = y_train['image']
y_train.drop('image', axis=1, inplace =True)

y_val['labal'] = y_val['image']
y_val.drop('image', axis = 1, inplace = True)

# %%
y_val['label'] = y_val['labal']

# %%
y_val.drop('labal',axis=1,inplace=True)

# %%
train_data = pd.concat([X_train,y_train], axis = 1)
val_data = pd.concat([X_val,y_val], axis = 1)

# %%
val_data.head()
# Out:
#                                                   image  \
# 2072  <PIL.Image.Image image mode=RGB size=512x512 a...
# 443   <PIL.Image.Image image mode=RGB size=512x512 a...
# 1397  <PIL.Image.Image image mode=RGB size=512x512 a...
# 2567  <PIL.Image.Image image mode=RGB size=512x512 a...
# 1017  <PIL.Image.Image image mode=RGB size=512x512 a...
#
#                                                   label
# 2072  <PIL.Image.Image image mode=L size=512x512 at ...
# 443   <PIL.Image.Image image mode=L size=512x512 at ...
# 1397  <PIL.Image.Image image mode=L size=512x512 at ...
# 2567  <PIL.Image.Image image mode=L size=512x512 at ...
# 1017  <PIL.Image.Image image mode=L size=512x512 at ...

# %%
train_dataset = dataset(train_data, transformer = transformer, label_trans=label_transform)
val_dataset = dataset(val_data, transformer = transformer, label_trans=label_transform)

# %%
image,_ = val_dataset[0]

# %%
type(_)
# Out:
# torch.Tensor

# %%
train_loader = DataLoader(train_dataset, batch_size = 3)
val_loader = DataLoader(val_dataset, batch_size = 3)

# %%
import torch
import torch.nn as nn

# %%
not_my_model = resnet50()

# %%
class DoubleConv(nn.Module):
    def __init__(self, in_channels, out_channels, mid_channels=None):
        super().__init__()
        if not mid_channels:
            mid_channels = out_channels
        self.double_conv = nn.Sequential(
            nn.Conv2d(in_channels, mid_channels, kernel_size=3, padding=1, bias=False),
            nn.BatchNorm2d(mid_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(mid_channels, out_channels, kernel_size=3, padding=1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True)
        )
    def forward(self, x):
        return self.double_conv(x)

class Down(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.maxpool_conv = nn.Sequential(nn.MaxPool2d(2), DoubleConv(in_channels, out_channels))
    def forward(self, x):
        return self.maxpool_conv(x)

class Up(nn.Module):
    """Upscaling then double conv, with crucial padding fix for non-power-of-2 sizes."""
    def __init__(self, in_channels, out_channels, bilinear=True):
        super().__init__()
        if bilinear:
            self.up = nn.Upsample(scale_factor=2, mode='bilinear', align_corners=True)
            self.conv = DoubleConv(in_channels, out_channels, in_channels // 2)
        else:
            self.up = nn.ConvTranspose2d(in_channels, in_channels // 2, kernel_size=2, stride=2)
            self.conv = DoubleConv(in_channels, out_channels)

    def forward(self, x1, x2):
        x1 = self.up(x1)
        # Pad x1 to match the size of x2 (the skip connection)
        diffY = x2.size()[2] - x1.size()[2]
        diffX = x2.size()[3] - x1.size()[3]
        x1 = nn.functional.pad(x1, [diffX // 2, diffX - diffX // 2, diffY // 2, diffY - diffY // 2])
        x = torch.cat([x2, x1], dim=1)
        return self.conv(x)

class OutConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(OutConv, self).__init__()
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size=1)
    def forward(self, x):
        return self.conv(x)

class Model(nn.Module):
    def __init__(self, n_channels=3, n_classes=2, bilinear=True):
        super(Model, self).__init__()
        self.n_channels = n_channels
        self.n_classes = n_classes
        self.bilinear = bilinear

        self.inc = DoubleConv(n_channels, 64)
        self.down1 = Down(64, 128)
        self.down2 = Down(128, 256)
        factor = 2 if bilinear else 1
        self.down3 = Down(256, 512 // factor)
        self.up1 = Up(512, 256 // factor, bilinear)
        self.up2 = Up(256, 128 // factor, bilinear)
        self.up3 = Up(128, 64, bilinear)
        self.outc = OutConv(64, n_classes)

    def forward(self, x):
        x1 = self.inc(x)
        x2 = self.down1(x1)
        x3 = self.down2(x2)
        x4 = self.down3(x3)
        x = self.up1(x4, x3)
        x = self.up2(x, x2)
        x = self.up3(x, x1)
        logits = self.outc(x)
        return logits

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
bohrium_model = Model()

# %%
optimizer = torch.optim.Adam(bohrium_model.parameters(), lr= 1e-3, weight_decay = 1e-4)
criterion = nn.CrossEntropyLoss()
bohrium_model.to(device)
# Out:
# Model(
#   (inc): DoubleConv(
#     (double_conv): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#   )
#   (down1): Down(
#     (maxpool_conv): Sequential(
#       (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (1): DoubleConv(
#         (double_conv): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#         )
#       )
#     )
#   )
#   (down2): Down(
#     (maxpool_conv): Sequential(
#       (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (1): DoubleConv(
#         (double_conv): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#         )
#       )
#     )
#   )
#   (down3): Down(
#     (maxpool_conv): Sequential(
#       (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (1): DoubleConv(
#         (double_conv): Sequential(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#         )
#       )
#     )
#   )
#   (up1): Up(
#     (up): Upsample(scale_factor=2.0, mode='bilinear')
#     (conv): DoubleConv(
#       (double_conv): Sequential(
#         (0): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#   )
#   (up2): Up(
#     (up): Upsample(scale_factor=2.0, mode='bilinear')
#     (conv): DoubleConv(
#       (double_conv): Sequential(
#         (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#   )
#   (up3): Up(
#     (up): Upsample(scale_factor=2.0, mode='bilinear')
#     (conv): DoubleConv(
#       (double_conv): Sequential(
#         (0): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#   )
#   (outc): OutConv(
#     (conv): Conv2d(64, 2, kernel_size=(1, 1), stride=(1, 1))
#   )
# )

# %%
from tqdm import tqdm
bohrium_model.train()
epochs = 20
losses = 0
for epoch in range(epochs):
    pbar = tqdm(train_loader, desc=f'the epoch {epoch+1}/{epochs} then :')
    for image, label in pbar:
        image = image.to(device)
        label = label.to(device)
        
        if label.dim() == 4 and label.size(1) == 1:
            label = label.squeeze(1)
        label = label.long()
        output = bohrium_model(image)
        optimizer.zero_grad()
        loss = criterion(output,label)
        loss.backward()
        optimizer.step()
        losses += loss.item()*image.size(0)
# Out:
# the epoch 1/20 then :: 100%|██████████| 91/91 [00:10<00:00,  8.65it/s]
# the epoch 2/20 then :: 100%|██████████| 91/91 [00:10<00:00,  8.32it/s]
# the epoch 3/20 then :: 100%|██████████| 91/91 [00:11<00:00,  8.21it/s]
# the epoch 4/20 then :: 100%|██████████| 91/91 [00:10<00:00,  8.31it/s]
# the epoch 5/20 then :: 100%|██████████| 91/91 [00:10<00:00,  8.49it/s]
# the epoch 6/20 then :: 100%|██████████| 91/91 [00:10<00:00,  8.68it/s]
# the epoch 7/20 then :: 100%|██████████| 91/91 [00:10<00:00,  8.74it/s]
# the epoch 8/20 then :: 100%|██████████| 91/91 [00:10<00:00,  8.70it/s]
# the epoch 9/20 then :: 100%|██████████| 91/91 [00:10<00:00,  8.66it/s]
# the epoch 10/20 then :: 100%|██████████| 91/91 [00:10<00:00,  8.56it/s]
# the epoch 11/20 then :: 100%|██████████| 91/91 [00:10<00:00,  8.50it/s]
# the epoch 12/20 then :: 100%|██████████| 91/91 [00:10<00:00,  8.55it/s]
# the epoch 13/20 then :: 100%|██████████| 91/91 [00:10<00:00,  8.59it/s]
# the epoch 14/20 then :: 100%|██████████| 91/91 [00:10<00:00,  8.55it/s]
# the epoch 15/20 then :: 100%|██████████| 91/91 [00:10<00:00,  8.55it/s]
# the epoch 16/20 then :: 100%|██████████| 91/91 [00:10<00:00,  8.56it/s]
# the epoch 17/20 then :: 100%|██████████| 91/91 [00:10<00:00,  8.59it/s]
# the epoch 18/20 then :: 100%|██████████| 91/91 [00:10<00:00,  8.62it/s]
# the epoch 19/20 then :: 100%|██████████| 91/91 [00:10<00:00,  8.63it/s]
# the epoch 20/20 then :: 100%|██████████| 91/91 [00:10<00:00,  8.59it/s]

# %%
bohrium_model.eval()
correct = 0
total = 0
best_loss = float(0.7)  # You forgot to define this before
criterion = nn.CrossEntropyLoss()  # If not already defined

pbar = tqdm(val_loader, desc='In evaluation:', leave=True)
for image, label in pbar:
    image = image.to(device)
    label = label.to(device).squeeze().long()  # Ensure label is in long format for CE Loss

    with torch.no_grad():
        output = bohrium_model(image)  # Shape: [B, C, H, W]
        prediction = torch.argmax(output, dim=1)  # Shape: [B, H, W]

        loss = criterion(output, label)

        correct += (prediction == label).sum().item()
        total += label.numel()

    # Update progress bar with loss and current accuracy
    pbar.set_postfix({
        'loss': loss.item(),
        'accuracy': f"{correct / total:.4f}"
    })

print(f'\nFinal Accuracy: {correct / total:.4f}')
# Out:
# In evaluation:: 100%|██████████| 816/816 [00:35<00:00, 22.87it/s, loss=0.101, accuracy=0.9245]
# Final Accuracy: 0.9245

# %%
img, lab = val_dataset[0]
image, label = val_dataset[1]

# %%
type(label)
# Out:
# torch.Tensor

# %%
output = bohrium_model(img.unsqueeze(0).to(device))
pred = torch.argmax(output, dim = 1).cpu()
output = bohrium_model(image.unsqueeze(0).to(device))
prediction = torch.argmax(output, dim = 1).cpu()

# %%
pred.shape
# Out:
# torch.Size([1, 224, 224])

# %%
label.shape
# Out:
# torch.Size([1, 224, 224])

# %%
import matplotlib.pyplot as plt

# Create a 2-row, 3-column plot
fig, axes = plt.subplots(2, 3, figsize=(12, 8))

# First row (img, lab, pred)
axes[0, 0].imshow(img.view(-1, 224, 224).permute(1, 2, 0).cpu().numpy())
axes[0, 0].set_title("Image 1")
axes[0, 0].axis("off")

axes[0, 1].imshow(lab.squeeze().cpu().numpy(), cmap='gray')
axes[0, 1].set_title("Mask 1")
axes[0, 1].axis("off")

axes[0, 2].imshow(pred.squeeze().cpu().numpy(), cmap='gray')
axes[0, 2].set_title("Prediction 1")
axes[0, 2].axis("off")

# Second row (image, label, prediction)
axes[1, 0].imshow(image.view(-1, 224, 224).permute(1, 2, 0).cpu().numpy())
axes[1, 0].set_title("Image 2")
axes[1, 0].axis("off")

axes[1, 1].imshow(label.squeeze().cpu().numpy(), cmap='gray')
axes[1, 1].set_title("Mask 2")
axes[1, 1].axis("off")

axes[1, 2].imshow(prediction.squeeze().cpu().numpy(), cmap='gray')
axes[1, 2].set_title("Prediction 2")
axes[1, 2].axis("off")

plt.tight_layout()
plt.show()
